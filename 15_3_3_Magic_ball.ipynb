# %%
import random

answer = ['Бесспорно', 'Предрешено', 'Никаких сомнений', 'Определённо да', 'Можешь быть уверен в этом', 'Мне кажется - да', 'Вероятнее всего', 'Хорошие перспективы', 'Знаки говорят - да', 'Да', 'Пока неясно, попробуй снова', 'Спроси позже', 'Лучше не рассказывать', 'Сейчас нельзя предсказать', 'Сконцентрируйся и спроси опять', 'Даже не думай', 'Мой ответ - нет', 'По моим данным - нет', 'Перспективы не очень хорошие', 'Весьма сомнительно']

print('Привет Мир, я магический шар, и я знаю ответ на любой твой вопрос.')

print('Привет,', input('Как вас зовут?').title() + '!')

question = ''
while question != 'да':
    print(input('Введите ваш вопрос'), random.choice(answer), end = '\n')
    if input('Хотите ли вы ещё задать вопрос? Напишите "да" или "нет"').lower() == 'да':
        question = ''
    else:
        print('Возвращайся если возникнут вопросы!')
        break
# Out:
# Привет Мир, я магический шар, и я знаю ответ на любой твой вопрос.
# Привет, Анастасия!
# Тима забил вкусную чашку? Можешь быть уверен в этом
# точно вкусную? Знаки говорят - да
# это будет десертный микс? Перспективы не очень хорошие
# Фруктовый? Никаких сомнений
# мы выбрали хорошее имя для попугая? Лучше не рассказывать
#  Лучше не рассказывать
# Возвращайся если возникнут вопросы!
