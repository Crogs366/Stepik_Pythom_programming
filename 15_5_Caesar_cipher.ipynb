# %%
eng_lower_alphabet = 'abcdefghijklmnopqrstuvwxyz'
eng_upper_alphabet = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
rus_lower_alphabet = "абвгдежзийклмнопрстуфхцчшщъыьэюя"
rus_upper_alphabet = "АБВГДЕЖЗИЙКЛМНОПРСТУФХЦЧШЩЪЫЬЭЮЯ"

txt = input('Введите текст')
direction = input('Введите направление: шифрование или дешифрование')
language = input('Введите язык алфавита: русский или английский').lower()
shift_step = int(input('Введите шаг сдвига'))
new_txt = ''
for i in txt:
    if direction == 'шифрование':
        if language == 'русский':
            if i in rus_lower_alphabet:
                x = rus_lower_alphabet.find(i)
                y = (x + shift_step) % len(rus_lower_alphabet)
                new_txt += rus_lower_alphabet[y]
            elif i in rus_upper_alphabet:
                x = rus_upper_alphabet.find(i)
                y = (x + shift_step) % len(rus_upper_alphabet)
                new_txt += rus_upper_alphabet[y]
            else:
                new_txt += i
        elif language == 'английский':
            if i in eng_lower_alphabet:
                x = eng_lower_alphabet.find(i)
                y = (x + shift_step) % len(eng_lower_alphabet)
                new_txt += eng_lower_alphabet[y]
            elif i in eng_upper_alphabet:
                x = eng_upper_alphabet.find(i)
                y = (x + shift_step) % len(eng_upper_alphabet)
                new_txt += eng_upper_alphabet[y]
            else:
                new_txt += i
    elif direction == 'дешифрование':
        if language == 'русский':
            if i in rus_lower_alphabet:
                x = rus_lower_alphabet.find(i)
                y = (x - shift_step) % len(rus_lower_alphabet)
                new_txt += rus_lower_alphabet[y]
            elif i in rus_upper_alphabet:
                x = rus_upper_alphabet.find(i)
                y = (x - shift_step) % len(rus_upper_alphabet)
                new_txt += rus_upper_alphabet[y]
            else:
                new_txt += i
        elif language == 'английский':
            if i in eng_lower_alphabet:
                x = eng_lower_alphabet.find(i)
                y = (x - shift_step) % len(eng_lower_alphabet)
                new_txt += eng_lower_alphabet[y]
            elif i in eng_upper_alphabet:
                x = eng_upper_alphabet.find(i)
                y = (x - shift_step) % len(eng_upper_alphabet)
                new_txt += eng_upper_alphabet[y]
            else:
                new_txt += i
print(new_txt)
# Out:
# Йсъшфвр зчиъо

# %%
eng_lower_alphabet = 'abcdefghijklmnopqrstuvwxyz'
eng_upper_alphabet = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
rus_lower_alphabet = "абвгдежзийклмнопрстуфхцчшщъыьэюя"
rus_upper_alphabet = "АБВГДЕЖЗИЙКЛМНОПРСТУФХЦЧШЩЪЫЬЭЮЯ"

txt = input('Введите текст')
direction = input('Введите направление: шифрование или дешифрование')
language = input('Введите язык алфавита: русский или английский').lower()
shift_step = int(input('Введите шаг сдвига'))
new_txt = ''
for j in range(25): 
    for i in txt:
        if direction == 'шифрование':
            if language == 'русский':
                if i in rus_lower_alphabet:
                    x = rus_lower_alphabet.find(i)
                    y = (x + shift_step) % len(rus_lower_alphabet)
                    new_txt += rus_lower_alphabet[y]
                elif i in rus_upper_alphabet:
                    x = rus_upper_alphabet.find(i)
                    y = (x + shift_step) % len(rus_upper_alphabet)
                    new_txt += rus_upper_alphabet[y]
                else:
                    new_txt += i
            elif language == 'английский':
                if i in eng_lower_alphabet:
                    x = eng_lower_alphabet.find(i)
                    y = (x + shift_step) % len(eng_lower_alphabet)
                    new_txt += eng_lower_alphabet[y]
                elif i in eng_upper_alphabet:
                    x = eng_upper_alphabet.find(i)
                    y = (x + shift_step) % len(eng_upper_alphabet)
                    new_txt += eng_upper_alphabet[y]
                else:
                    new_txt += i
        elif direction == 'дешифрование':
            if language == 'русский':
                if i in rus_lower_alphabet:
                    x = rus_lower_alphabet.find(i)
                    y = (x - shift_step) % len(rus_lower_alphabet)
                    new_txt += rus_lower_alphabet[y]
                elif i in rus_upper_alphabet:
                    x = rus_upper_alphabet.find(i)
                    y = (x - shift_step) % len(rus_upper_alphabet)
                    new_txt += rus_upper_alphabet[y]
                else:
                    new_txt += i
            elif language == 'английский':
                if i in eng_lower_alphabet:
                    x = eng_lower_alphabet.find(i)
                    y = (x - j) % len(eng_lower_alphabet)
                    new_txt += eng_lower_alphabet[y]
                elif i in eng_upper_alphabet:
                    x = eng_upper_alphabet.find(i)
                    y = (x - j) % len(eng_upper_alphabet)
                    new_txt += eng_upper_alphabet[y]
                else:
                    new_txt += i
print(new_txt)
# Out:
# Hawnj pk swhg xabkna ukq nqj.Gzvmi oj rvgf wzajmz tjp mpi.Fyulh ni qufe vyzily sio loh.Extkg mh pted uxyhkx rhn kng.Dwsjf lg osdc twxgjw qgm jmf.Cvrie kf nrcb svwfiv pfl ile.Buqhd je mqba ruvehu oek hkd.Atpgc id lpaz qtudgt ndj gjc.Zsofb hc kozy pstcfs mci fib.Yrnea gb jnyx orsber lbh eha.Xqmdz fa imxw nqradq kag dgz.Wplcy ez hlwv mpqzcp jzf cfy.Vokbx dy gkvu lopybo iye bex.Unjaw cx fjut knoxan hxd adw.Tmizv bw eits jmnwzm gwc zcv.Slhyu av dhsr ilmvyl fvb ybu.Rkgxt zu cgrq hkluxk eua xat.Qjfws yt bfqp gjktwj dtz wzs.Pievr xs aepo fijsvi csy vyr.Ohduq wr zdon ehiruh brx uxq.Ngctp vq ycnm dghqtg aqw twp.Mfbso up xbml cfgpsf zpv svo.Learn to walk before you run.Kdzqm sn vzkj adenqd xnt qtm.Jcypl rm uyji zcdmpc wms psl.

# %%
eng_lower_alphabet = 'abcdefghijklmnopqrstuvwxyz'
eng_upper_alphabet = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

txt = input()
shift_step = ''
new_txt = ''
for i in txt:
    if i in eng_lower_alphabet:
        shift_step += i
    elif i in eng_upper_alphabet:
        shift_step += i
    elif i == '-':
        shift_step += i
    else:
        for j in shift_step:
            if j in eng_lower_alphabet: 
                x = eng_lower_alphabet.find(j)
                y = (x + len(shift_step)) % len(eng_lower_alphabet)
                new_txt += eng_lower_alphabet[y]
            if j in eng_upper_alphabet: 
                x = eng_upper_alphabet.find(j)
                y = (x + len(shift_step)) % len(eng_upper_alphabet)
                new_txt += eng_upper_alphabet[y] 
            if j == '-':
                new_txt += '-'
        new_txt += i
        shift_step = ''
if len(shift_step) + len(new_txt) == len(txt):
    for j in shift_step:
        if j in eng_lower_alphabet: 
            x = eng_lower_alphabet.find(j)
            y = (x + len(shift_step)) % len(eng_lower_alphabet)
            new_txt += eng_lower_alphabet[y]
        if j in eng_upper_alphabet: 
            x = eng_upper_alphabet.find(j)
            y = (x + len(shift_step)) % len(eng_upper_alphabet)
            new_txt += eng_upper_alphabet[y]
        if j == '-':
            new_txt += '-'
print(new_txt)
